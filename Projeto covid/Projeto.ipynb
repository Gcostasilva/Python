# %% [markdown]
# # *Análise de dados*

# %% [markdown]
# ## Covid - Fevereiro 2020 a setembro 2021

# %% [markdown]
# ### Importação

# %%
import pandas as pd
import numpy as np

# %%
covid = pd.read_csv('dados_covid_sp.csv', sep=';', encoding="utf-8")

# %%
covid .head(5)
# Out:
#          nome_munic  codigo_ibge  dia  mes    datahora  casos  casos_novos  \
# 0        Adamantina      3500105   25    2  2020-02-25      0            0
# 1            Adolfo      3500204   25    2  2020-02-25      0            0
# 2             Aguaí      3500303   25    2  2020-02-25      0            0
# 3    Águas da Prata      3500402   25    2  2020-02-25      0            0
# 4  Águas de Lindóia      3500501   25    2  2020-02-25      0            0
#
#                casos_pc         casos_mm7d  obitos  ...  \
# 0  0,00000000000000e+00  0,000000000000000       0  ...
# 1  0,00000000000000e+00  0,000000000000000       0  ...
# 2  0,00000000000000e+00  0,000000000000000       0  ...
# 3  0,00000000000000e+00  0,000000000000000       0  ...
# 4  0,00000000000000e+00  0,000000000000000       0  ...
#
#                 nome_drs cod_drs    pop pop_60   area  map_leg map_leg_s  \
# 0                Marília       5  33894   7398  41199        0       8.0
# ...

# %%
covid.shape
# Out:
# (374034, 26)

# %% [markdown]
# ### Alteração

# %% [markdown]
# ##### Altera o nome das colunas

# %%
covid.rename(columns={'nome_munic':'Município', 'datahora':'Data'}, inplace=True)

# %% [markdown]
# #### Exclui as colunas

# %%
covid_alter = covid.drop(columns={'cod_ra'})

# %%
covid_alter.head(4)
# Out:
#         Município  codigo_ibge  dia  mes        Data  casos  casos_novos  \
# 0      Adamantina      3500105   25    2  2020-02-25      0            0
# 1          Adolfo      3500204   25    2  2020-02-25      0            0
# 2           Aguaí      3500303   25    2  2020-02-25      0            0
# 3  Águas da Prata      3500402   25    2  2020-02-25      0            0
#
#                casos_pc         casos_mm7d  obitos  ...  \
# 0  0,00000000000000e+00  0,000000000000000       0  ...
# 1  0,00000000000000e+00  0,000000000000000       0  ...
# 2  0,00000000000000e+00  0,000000000000000       0  ...
# 3  0,00000000000000e+00  0,000000000000000       0  ...
#
#                 nome_drs cod_drs    pop pop_60   area map_leg  map_leg_s  \
# 0                Marília       5  33894   7398  41199       0        8.0
# 1  São José do Rio Preto      15   3447    761  21106       0        8.0
# 2  São João da Boa Vista      14  35608   5245  47455       0        8.0
# ...

# %%
covid_alter.shape
# Out:
# (374034, 25)

# %% [markdown]
# Alterando direto dentro do dataset sem criar cópia
#
# axis = 0 para linhas
# axis = 1 para colunas
#
# O índice da coluna entre colchetes duplos [[1]]
#
# Aqui exclui a coluna/variável pelo índice dela começando em 0

# %%
covid_alter = covid_alter.drop(covid_alter.columns[[1]], axis=1)
covid_alter.head(5)
# Out:
#           Município  dia  mes        Data  casos  casos_novos  \
# 0        Adamantina   25    2  2020-02-25      0            0
# 1            Adolfo   25    2  2020-02-25      0            0
# 2             Aguaí   25    2  2020-02-25      0            0
# 3    Águas da Prata   25    2  2020-02-25      0            0
# 4  Águas de Lindóia   25    2  2020-02-25      0            0
#
#                casos_pc         casos_mm7d  obitos  obitos_novos  ...  \
# 0  0,00000000000000e+00  0,000000000000000       0             0  ...
# 1  0,00000000000000e+00  0,000000000000000       0             0  ...
# 2  0,00000000000000e+00  0,000000000000000       0             0  ...
# 3  0,00000000000000e+00  0,000000000000000       0             0  ...
# 4  0,00000000000000e+00  0,000000000000000       0             0  ...
#
#                 nome_drs cod_drs    pop pop_60   area  map_leg  map_leg_s  \
# 0                Marília       5  33894   7398  41199        0        8.0
# ...

# %% [markdown]
# Aqui apaga pelo nome da coluna/variável

# %%
covid_alter.drop(columns=['cod_drs', 'map_leg', 'map_leg_s'], inplace=True)
covid_alter.shape
# Out:
# (374034, 21)

# %% [markdown]
# #### Altera o valor das linhas

# %% [markdown]
# Aqui altera o valor da variável área, fazendo a divisão por 100

# %%
#covid_alter = covid_alter.area / 100 # Das duas formas funciona
covid_alter['area'] = covid_alter['area'] / 100

# %%
covid_alter.head(5)
# Out:
#           Município  dia  mes        Data  casos  casos_novos  \
# 0        Adamantina   25    2  2020-02-25      0            0
# 1            Adolfo   25    2  2020-02-25      0            0
# 2             Aguaí   25    2  2020-02-25      0            0
# 3    Águas da Prata   25    2  2020-02-25      0            0
# 4  Águas de Lindóia   25    2  2020-02-25      0            0
#
#                casos_pc         casos_mm7d  obitos  obitos_novos  ...  \
# 0  0,00000000000000e+00  0,000000000000000       0             0  ...
# 1  0,00000000000000e+00  0,000000000000000       0             0  ...
# 2  0,00000000000000e+00  0,000000000000000       0             0  ...
# 3  0,00000000000000e+00  0,000000000000000       0             0  ...
# 4  0,00000000000000e+00  0,000000000000000       0             0  ...
#
#          obitos_mm7d            letalidade                      nome_ra  \
# 0  0,000000000000000  0,000000000000000000    RA de Presidente Prudente
# ...

# %% [markdown]
# #### Cria coluna
#
# Com base na população / a área se chega na densidade por km²

# %%
covid_alter['densidade'] = covid_alter['pop'] / covid_alter['area']
covid_alter.head(5)
# Out:
#           Município  dia  mes        Data  casos  casos_novos  \
# 0        Adamantina   25    2  2020-02-25      0            0
# 1            Adolfo   25    2  2020-02-25      0            0
# 2             Aguaí   25    2  2020-02-25      0            0
# 3    Águas da Prata   25    2  2020-02-25      0            0
# 4  Águas de Lindóia   25    2  2020-02-25      0            0
#
#                casos_pc         casos_mm7d  obitos  obitos_novos  ...  \
# 0  0,00000000000000e+00  0,000000000000000       0             0  ...
# 1  0,00000000000000e+00  0,000000000000000       0             0  ...
# 2  0,00000000000000e+00  0,000000000000000       0             0  ...
# 3  0,00000000000000e+00  0,000000000000000       0             0  ...
# 4  0,00000000000000e+00  0,000000000000000       0             0  ...
#
#              letalidade                      nome_ra               nome_drs  \
# 0  0,000000000000000000    RA de Presidente Prudente                Marília
# ...

# %%
#Alterar o nome da coluna para que o dataset fique mais compreensivel
covid_alter.rename(columns={'densidade':'Densidade /KM²'}, inplace=True)

# %%
covid_alter.head(5)
# Out:
#           Município  dia  mes        Data  casos  casos_novos  \
# 0        Adamantina   25    2  2020-02-25      0            0
# 1            Adolfo   25    2  2020-02-25      0            0
# 2             Aguaí   25    2  2020-02-25      0            0
# 3    Águas da Prata   25    2  2020-02-25      0            0
# 4  Águas de Lindóia   25    2  2020-02-25      0            0
#
#                casos_pc         casos_mm7d  obitos  obitos_novos  ...  \
# 0  0,00000000000000e+00  0,000000000000000       0             0  ...
# 1  0,00000000000000e+00  0,000000000000000       0             0  ...
# 2  0,00000000000000e+00  0,000000000000000       0             0  ...
# 3  0,00000000000000e+00  0,000000000000000       0             0  ...
# 4  0,00000000000000e+00  0,000000000000000       0             0  ...
#
#              letalidade                      nome_ra               nome_drs  \
# 0  0,000000000000000000    RA de Presidente Prudente                Marília
# ...

# %%
#list.range cria uma lista que vai de 1 até o final da contagem de densidade
covid_alter.shape
lista = list(range(1,len(covid_alter['Densidade /KM²'])+2))
lista[-1:]
# Out:
# [374035]

# %%
df = pd.DataFrame(lista, columns=['Índice'])
df
# Out:
#         Índice
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ...        ...
# 374030  374031
# 374031  374032
# 374032  374033
# 374033  374034
# 374034  374035
#
# [374035 rows x 1 columns]

# %%
#axis = 1 para indicar que está concatenando colunam, se fossem arquivos, 'acrescentando', seria axis = 0
covid_alter = pd.concat([covid_alter, df], axis = 1)
covid_alter.head(5)
# Out:
#           Município   dia  mes        Data  casos  casos_novos  \
# 0        Adamantina  25.0  2.0  2020-02-25    0.0          0.0
# 1            Adolfo  25.0  2.0  2020-02-25    0.0          0.0
# 2             Aguaí  25.0  2.0  2020-02-25    0.0          0.0
# 3    Águas da Prata  25.0  2.0  2020-02-25    0.0          0.0
# 4  Águas de Lindóia  25.0  2.0  2020-02-25    0.0          0.0
#
#                casos_pc         casos_mm7d  obitos  obitos_novos  ...  \
# 0  0,00000000000000e+00  0,000000000000000     0.0           0.0  ...
# 1  0,00000000000000e+00  0,000000000000000     0.0           0.0  ...
# 2  0,00000000000000e+00  0,000000000000000     0.0           0.0  ...
# 3  0,00000000000000e+00  0,000000000000000     0.0           0.0  ...
# 4  0,00000000000000e+00  0,000000000000000     0.0           0.0  ...
#
#                        nome_ra               nome_drs      pop  pop_60  \
# 0    RA de Presidente Prudente                Marília  33894.0  7398.0
# ...

# %% [markdown]
# ####  Filtro

# %%
covid_alter['Município'].value_counts().sort_index()
# Out:
# Município
# Adamantina            579
# Adolfo                579
# Aguaí                 579
# Agudos                579
# Alambari              579
#                      ...
# Águas de São Pedro    579
# Álvares Florence      579
# Álvares Machado       579
# Álvaro de Carvalho    579
# Óleo                  579
# Name: count, Length: 646, dtype: int64

# %%
#covid_alter.head(5)
covid_alter.query('obitos_novos >10')['Município'].value_counts()
# Out:
# Município
# São Paulo                476
# Guarulhos                171
# Campinas                 166
# São Bernardo do Campo    103
# Santo André               94
#                         ...
# Ipaussu                    1
# Santana de Parnaíba        1
# Cosmópolis                 1
# Tatuí                      1
# Andradina                  1
# Name: count, Length: 110, dtype: int64

# %% [markdown]
# #### Visualização em partes

# %%
novo_df3 = covid_alter.iloc[: , :5]
novo_df3
# Out:
#                Município   dia  mes        Data   casos
# 0             Adamantina  25.0  2.0  2020-02-25     0.0
# 1                 Adolfo  25.0  2.0  2020-02-25     0.0
# 2                  Aguaí  25.0  2.0  2020-02-25     0.0
# 3         Águas da Prata  25.0  2.0  2020-02-25     0.0
# 4       Águas de Lindóia  25.0  2.0  2020-02-25     0.0
# ...                  ...   ...  ...         ...     ...
# 374030          Ignorado  22.0  9.0  2021-09-22  1414.0
# 374031          Ignorado  23.0  9.0  2021-09-23   962.0
# 374032          Ignorado  24.0  9.0  2021-09-24   557.0
# 374033          Ignorado  25.0  9.0  2021-09-25   128.0
# 374034               NaN   NaN  NaN         NaN     NaN
#
# [374035 rows x 5 columns]

# %%
novo_df.query('casos > 1250')['Município'].value_counts()
# Out:
# Município
# São Paulo                  544
# Osasco                     504
# Guarulhos                  500
# São Bernardo do Campo      500
# Santos                     499
#                           ...
# Pacaembu                    44
# Chavantes                   40
# Pinhalzinho                 37
# Piratininga                 25
# Mirante do Paranapanema      9
# Name: count, Length: 351, dtype: int64

# %% [markdown]
# #### Exclusão de linhas

# %% [markdown]
# ##### Valor Absoluto, linha específica

# %%
novo_df2 = covid_alter.drop(novo_df.index[[1,3]])
novo_df2
# Out:
#                      Município   dia  mes        Data   casos  casos_novos  \
# 0                   Adamantina  25.0  2.0  2020-02-25     0.0          0.0
# 2                        Aguaí  25.0  2.0  2020-02-25     0.0          0.0
# 4             Águas de Lindóia  25.0  2.0  2020-02-25     0.0          0.0
# 5       Águas de Santa Bárbara  25.0  2.0  2020-02-25     0.0          0.0
# 6           Águas de São Pedro  25.0  2.0  2020-02-25     0.0          0.0
# ...                        ...   ...  ...         ...     ...          ...
# 374030                Ignorado  22.0  9.0  2021-09-22  1414.0       -542.0
# 374031                Ignorado  23.0  9.0  2021-09-23   962.0       -452.0
# 374032                Ignorado  24.0  9.0  2021-09-24   557.0       -405.0
# 374033                Ignorado  25.0  9.0  2021-09-25   128.0       -429.0
# 374034                     NaN   NaN  NaN         NaN     NaN          NaN
#
# ...

# %% [markdown]
# ##### Exclusão por intervalo de valores, da 4º a 6º linha por exemplo
#
# Lembrar de colocar um a mais no final do range visto que o ultimo é excluido

# %%
novo_df2 = covid_alter.drop(novo_df.index[4:7])
novo_df2
# Out:
#              Município   dia  mes        Data   casos  casos_novos  \
# 0           Adamantina  25.0  2.0  2020-02-25     0.0          0.0
# 1               Adolfo  25.0  2.0  2020-02-25     0.0          0.0
# 2                Aguaí  25.0  2.0  2020-02-25     0.0          0.0
# 3       Águas da Prata  25.0  2.0  2020-02-25     0.0          0.0
# 7               Agudos  25.0  2.0  2020-02-25     0.0          0.0
# ...                ...   ...  ...         ...     ...          ...
# 374030        Ignorado  22.0  9.0  2021-09-22  1414.0       -542.0
# 374031        Ignorado  23.0  9.0  2021-09-23   962.0       -452.0
# 374032        Ignorado  24.0  9.0  2021-09-24   557.0       -405.0
# 374033        Ignorado  25.0  9.0  2021-09-25   128.0       -429.0
# 374034             NaN   NaN  NaN         NaN     NaN          NaN
#
#                     casos_pc             casos_mm7d  obitos  obitos_novos  \
# 0       0,00000000000000e+00      0,000000000000000     0.0           0.0
# ...

# %% [markdown]
# ##### Resetar os índices
#
# drop = True para excluir o índice antigo

# %%
novo_df2 = novo_df2.reset_index(drop=True)
novo_df2
# Out:
#              Município   dia  mes        Data   casos  casos_novos  \
# 0           Adamantina  25.0  2.0  2020-02-25     0.0          0.0
# 1               Adolfo  25.0  2.0  2020-02-25     0.0          0.0
# 2                Aguaí  25.0  2.0  2020-02-25     0.0          0.0
# 3       Águas da Prata  25.0  2.0  2020-02-25     0.0          0.0
# 4               Agudos  25.0  2.0  2020-02-25     0.0          0.0
# ...                ...   ...  ...         ...     ...          ...
# 374027        Ignorado  22.0  9.0  2021-09-22  1414.0       -542.0
# 374028        Ignorado  23.0  9.0  2021-09-23   962.0       -452.0
# 374029        Ignorado  24.0  9.0  2021-09-24   557.0       -405.0
# 374030        Ignorado  25.0  9.0  2021-09-25   128.0       -429.0
# 374031             NaN   NaN  NaN         NaN     NaN          NaN
#
#                     casos_pc             casos_mm7d  obitos  obitos_novos  \
# 0       0,00000000000000e+00      0,000000000000000     0.0           0.0
# ...

# %% [markdown]
# ##### Localizar os dados onde município está como ignorado

# %%
ignorados = novo_df2.loc[novo_df2['Município'] == 'Ignorado']
ignorados
# Out:
#        Município   dia  mes        Data   casos  casos_novos  \
# 373452  Ignorado  25.0  2.0  2020-02-25    -1.0          0.0
# 373453  Ignorado  26.0  2.0  2020-02-26     0.0          1.0
# 373454  Ignorado  27.0  2.0  2020-02-27     0.0          0.0
# 373455  Ignorado  28.0  2.0  2020-02-28    -1.0         -1.0
# 373456  Ignorado  29.0  2.0  2020-02-29     0.0          1.0
# ...          ...   ...  ...         ...     ...          ...
# 374026  Ignorado  21.0  9.0  2021-09-21  1956.0       -477.0
# 374027  Ignorado  22.0  9.0  2021-09-22  1414.0       -542.0
# 374028  Ignorado  23.0  9.0  2021-09-23   962.0       -452.0
# 374029  Ignorado  24.0  9.0  2021-09-24   557.0       -405.0
# 374030  Ignorado  25.0  9.0  2021-09-25   128.0       -429.0
#
#                     casos_pc             casos_mm7d  obitos  obitos_novos  \
# 373452  0,00000000000000e+00      0,000000000000000     0.0           0.0
# 373453  0,00000000000000e+00      0,000000000000000     0.0           0.0
# ...

# %% [markdown]
# ##### Exclui linhas com base em um critério

# %%
novo_df2 = novo_df2.loc[novo_df2['Município'] != 'Ignorado']
novo_df2
# Out:
#              Município   dia  mes        Data    casos  casos_novos  \
# 0           Adamantina  25.0  2.0  2020-02-25      0.0          0.0
# 1               Adolfo  25.0  2.0  2020-02-25      0.0          0.0
# 2                Aguaí  25.0  2.0  2020-02-25      0.0          0.0
# 3       Águas da Prata  25.0  2.0  2020-02-25      0.0          0.0
# 4               Agudos  25.0  2.0  2020-02-25      0.0          0.0
# ...                ...   ...  ...         ...      ...          ...
# 373448     Votuporanga  25.0  9.0  2021-09-25  16147.0          9.0
# 373449        Zacarias  25.0  9.0  2021-09-25    268.0          0.0
# 373450       Chavantes  25.0  9.0  2021-09-25   1388.0          0.0
# 373451    Estiva Gerbi  25.0  9.0  2021-09-25    811.0          0.0
# 374031             NaN   NaN  NaN         NaN      NaN          NaN
#
#                     casos_pc         casos_mm7d  obitos  obitos_novos  ...  \
# ...

# %% [markdown]
# ### Filtrar com base em um critério

# %%
guarulhos = novo_df2.loc[novo_df2['Município'] == 'Guarulhos'].copy() #não esquecer o .copy
guarulhos
# Out:
#         Município   dia  mes        Data    casos  casos_novos  \
# 209     Guarulhos  25.0  2.0  2020-02-25      0.0          0.0
# 854     Guarulhos  26.0  2.0  2020-02-26      0.0          0.0
# 1499    Guarulhos  27.0  2.0  2020-02-27      0.0          0.0
# 2144    Guarulhos  28.0  2.0  2020-02-28      0.0          0.0
# 2789    Guarulhos  29.0  2.0  2020-02-29      0.0          0.0
# ...           ...   ...  ...         ...      ...          ...
# 370439  Guarulhos  21.0  9.0  2021-09-21  63334.0         28.0
# 371084  Guarulhos  22.0  9.0  2021-09-22  63351.0         17.0
# 371729  Guarulhos  23.0  9.0  2021-09-23  63368.0         17.0
# 372374  Guarulhos  24.0  9.0  2021-09-24  63387.0         19.0
# 373019  Guarulhos  25.0  9.0  2021-09-25  63398.0         11.0
#
#                     casos_pc           casos_mm7d  obitos  obitos_novos  ...  \
# 209     0,00000000000000e+00    0,000000000000000     0.0           0.0  ...
# ...

# %%
guarulhos.drop(columns=['dia', 'mes'], inplace=True)
guarulhos
# Out:
#         Município        Data    casos  casos_novos              casos_pc  \
# 209     Guarulhos  2020-02-25      0.0          0.0  0,00000000000000e+00
# 854     Guarulhos  2020-02-26      0.0          0.0  0,00000000000000e+00
# 1499    Guarulhos  2020-02-27      0.0          0.0  0,00000000000000e+00
# 2144    Guarulhos  2020-02-28      0.0          0.0  0,00000000000000e+00
# 2789    Guarulhos  2020-02-29      0.0          0.0  0,00000000000000e+00
# ...           ...         ...      ...          ...                   ...
# 370439  Guarulhos  2021-09-21  63334.0         28.0  4,68698081441602e+03
# 371084  Guarulhos  2021-09-22  63351.0         17.0  4,68823888549703e+03
# 371729  Guarulhos  2021-09-23  63368.0         17.0  4,68949695657805e+03
# 372374  Guarulhos  2021-09-24  63387.0         19.0  4,69090303602154e+03
# 373019  Guarulhos  2021-09-25  63398.0         11.0  4,69171708201513e+03
#
#                  casos_mm7d  obitos  obitos_novos             obitos_pc  \
# ...

# %%
guarulhos['semana_epidem'] = guarulhos['semana_epidem'].replace({9:'nove', 10:'dez'})
guarulhos
# Out:
#         Município        Data    casos  casos_novos              casos_pc  \
# 209     Guarulhos  2020-02-25      0.0          0.0  0,00000000000000e+00
# 854     Guarulhos  2020-02-26      0.0          0.0  0,00000000000000e+00
# 1499    Guarulhos  2020-02-27      0.0          0.0  0,00000000000000e+00
# 2144    Guarulhos  2020-02-28      0.0          0.0  0,00000000000000e+00
# 2789    Guarulhos  2020-02-29      0.0          0.0  0,00000000000000e+00
# ...           ...         ...      ...          ...                   ...
# 370439  Guarulhos  2021-09-21  63334.0         28.0  4,68698081441602e+03
# 371084  Guarulhos  2021-09-22  63351.0         17.0  4,68823888549703e+03
# 371729  Guarulhos  2021-09-23  63368.0         17.0  4,68949695657805e+03
# 372374  Guarulhos  2021-09-24  63387.0         19.0  4,69090303602154e+03
# 373019  Guarulhos  2021-09-25  63398.0         11.0  4,69171708201513e+03
#
#                  casos_mm7d  obitos  obitos_novos             obitos_pc  \
# ...

# %%
guarulhos['Município'] = guarulhos['Município'].replace({'Guarulhos':'Guarulhos - SP'})
guarulhos
# Out:
#              Município        Data    casos  casos_novos  \
# 209     Guarulhos - SP  2020-02-25      0.0          0.0
# 854     Guarulhos - SP  2020-02-26      0.0          0.0
# 1499    Guarulhos - SP  2020-02-27      0.0          0.0
# 2144    Guarulhos - SP  2020-02-28      0.0          0.0
# 2789    Guarulhos - SP  2020-02-29      0.0          0.0
# ...                ...         ...      ...          ...
# 370439  Guarulhos - SP  2021-09-21  63334.0         28.0
# 371084  Guarulhos - SP  2021-09-22  63351.0         17.0
# 371729  Guarulhos - SP  2021-09-23  63368.0         17.0
# 372374  Guarulhos - SP  2021-09-24  63387.0         19.0
# 373019  Guarulhos - SP  2021-09-25  63398.0         11.0
#
#                     casos_pc           casos_mm7d  obitos  obitos_novos  \
# 209     0,00000000000000e+00    0,000000000000000     0.0           0.0
# 854     0,00000000000000e+00    0,000000000000000     0.0           0.0
# ...

# %%
guarulhos['casos_pc'] = guarulhos['casos_pc'].apply(lambda x: x.replace(',','.'))
guarulhos
# Out:
#              Município        Data    casos  casos_novos  \
# 209     Guarulhos - SP  2020-02-25      0.0          0.0
# 854     Guarulhos - SP  2020-02-26      0.0          0.0
# 1499    Guarulhos - SP  2020-02-27      0.0          0.0
# 2144    Guarulhos - SP  2020-02-28      0.0          0.0
# 2789    Guarulhos - SP  2020-02-29      0.0          0.0
# ...                ...         ...      ...          ...
# 370439  Guarulhos - SP  2021-09-21  63334.0         28.0
# 371084  Guarulhos - SP  2021-09-22  63351.0         17.0
# 371729  Guarulhos - SP  2021-09-23  63368.0         17.0
# 372374  Guarulhos - SP  2021-09-24  63387.0         19.0
# 373019  Guarulhos - SP  2021-09-25  63398.0         11.0
#
#                     casos_pc           casos_mm7d  obitos  obitos_novos  \
# 209     0.00000000000000e+00    0,000000000000000     0.0           0.0
# 854     0.00000000000000e+00    0,000000000000000     0.0           0.0
# ...

# %%
guarulhos['casos_novos'] = guarulhos['casos_mm7d'].apply(lambda x: x.replace(',','.'))
guarulhos
# Out:
#              Município        Data    casos          casos_novos  \
# 209     Guarulhos - SP  2020-02-25      0.0    0.000000000000000
# 854     Guarulhos - SP  2020-02-26      0.0    0.000000000000000
# 1499    Guarulhos - SP  2020-02-27      0.0    0.000000000000000
# 2144    Guarulhos - SP  2020-02-28      0.0    0.000000000000000
# 2789    Guarulhos - SP  2020-02-29      0.0    0.000000000000000
# ...                ...         ...      ...                  ...
# 370439  Guarulhos - SP  2021-09-21  63334.0  102.571428571428569
# 371084  Guarulhos - SP  2021-09-22  63351.0  105.000000000000000
# 371729  Guarulhos - SP  2021-09-23  63368.0  107.285714285714292
# 372374  Guarulhos - SP  2021-09-24  63387.0   61.285714285714285
# 373019  Guarulhos - SP  2021-09-25  63398.0   14.142857142857142
#
#                     casos_pc           casos_mm7d  obitos  obitos_novos  \
# 209     0.00000000000000e+00    0,000000000000000     0.0           0.0
# ...

# %% [markdown]
# ### Tratando valores faltantes

# %% [markdown]
# #### Identificando

# %%
## Exibe os valores que com nulos por variável
covid_alter.isnull().sum()
# adicionar ['COLUNA] após o dataset para ver de uma coluna em específico
# Out:
# Município           1
# dia                 1
# mes                 1
# Data                1
# casos               1
# casos_novos         1
# casos_pc            1
# casos_mm7d          1
# obitos              1
# obitos_novos        1
# obitos_pc           1
# obitos_mm7d         1
# letalidade          1
# nome_ra           580
# nome_drs          580
# pop                 1
# pop_60              1
# area                1
# latitude            1
# longitude           1
# semana_epidem       1
# Densidade /KM²    580
# Índice              0
# dtype: int64

# %% [markdown]
# #### Excluindo as linhas que contenham valores ausentes, DROPNA

# %%
covid_alter2 = covid_alter.dropna()

# %%
covid_alter2.isnull().sum()
# Out:
# Município         0
# dia               0
# mes               0
# Data              0
# casos             0
# casos_novos       0
# casos_pc          0
# casos_mm7d        0
# obitos            0
# obitos_novos      0
# obitos_pc         0
# obitos_mm7d       0
# letalidade        0
# nome_ra           0
# nome_drs          0
# pop               0
# pop_60            0
# area              0
# latitude          0
# longitude         0
# semana_epidem     0
# Densidade /KM²    0
# Índice            0
# dtype: int64

# %% [markdown]
# ##### Substituindo valores ausentes

# %%
# Médiana
covid_alter2['obitos_novos'].fillna(covid_alter2['obitos_novos'].median(), inplace=True)

# Média
covid_alter2['obitos_novos'].fillna(covid_alter2['obitos_novos'].mean, inplace=True)

#Qualquer valor
covid_alter2['obitos_novos'].fillna(10, inplace=True)
# Out:
# C:\Users\guico\AppData\Local\Temp\ipykernel_22820\4036951406.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   covid_alter2['obitos_novos'].fillna(covid_alter2['obitos_novos'].median(), inplace=True)
# C:\Users\guico\AppData\Local\Temp\ipykernel_22820\4036951406.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# ### Classificação e alteração da tipagem das variáveis
#
# object      : strings
#
# int64       : inteiros
#
# float64     : reais
#
# complex     : complexos

# %%
covid_alter.dtypes
# Out:
# Município          object
# dia               float64
# mes               float64
# Data               object
# casos             float64
# casos_novos       float64
# casos_pc           object
# casos_mm7d         object
# obitos            float64
# obitos_novos      float64
# obitos_pc          object
# obitos_mm7d        object
# letalidade         object
# nome_ra            object
# nome_drs           object
# pop               float64
# pop_60            float64
# area              float64
# latitude           object
# longitude          object
# semana_epidem     float64
# Densidade /KM²    float64
# Índice              int64
# dtype: object

# %%
covid_alter['casos_pc']
# Out:
# 0         0,00000000000000e+00
# 1         0,00000000000000e+00
# 2         0,00000000000000e+00
# 3         0,00000000000000e+00
# 4         0,00000000000000e+00
#                   ...
# 374030    0,00000000000000e+00
# 374031    0,00000000000000e+00
# 374032    0,00000000000000e+00
# 374033    0,00000000000000e+00
# 374034                     NaN
# Name: casos_pc, Length: 374035, dtype: object

# %%
covid_alter['casos_pc'] = covid_alter['casos_pc'].astype(str).str.replace(',','.').astype(float)
covid_alter
# Out:
#                Município   dia  mes        Data   casos  casos_novos  \
# 0             Adamantina  25.0  2.0  2020-02-25     0.0          0.0
# 1                 Adolfo  25.0  2.0  2020-02-25     0.0          0.0
# 2                  Aguaí  25.0  2.0  2020-02-25     0.0          0.0
# 3         Águas da Prata  25.0  2.0  2020-02-25     0.0          0.0
# 4       Águas de Lindóia  25.0  2.0  2020-02-25     0.0          0.0
# ...                  ...   ...  ...         ...     ...          ...
# 374030          Ignorado  22.0  9.0  2021-09-22  1414.0       -542.0
# 374031          Ignorado  23.0  9.0  2021-09-23   962.0       -452.0
# 374032          Ignorado  24.0  9.0  2021-09-24   557.0       -405.0
# 374033          Ignorado  25.0  9.0  2021-09-25   128.0       -429.0
# 374034               NaN   NaN  NaN         NaN     NaN          NaN
#
#         casos_pc             casos_mm7d  obitos  obitos_novos  ...  \
# 0            0.0      0,000000000000000     0.0           0.0  ...
# ...

# %%
covid_alter = covid_alter.loc[covid_alter['Município'] != 'Ignorado']

# %%
covid_alter
# Out:
#                Município   dia  mes        Data    casos  casos_novos  \
# 0             Adamantina  25.0  2.0  2020-02-25      0.0          0.0
# 1                 Adolfo  25.0  2.0  2020-02-25      0.0          0.0
# 2                  Aguaí  25.0  2.0  2020-02-25      0.0          0.0
# 3         Águas da Prata  25.0  2.0  2020-02-25      0.0          0.0
# 4       Águas de Lindóia  25.0  2.0  2020-02-25      0.0          0.0
# ...                  ...   ...  ...         ...      ...          ...
# 373451       Votuporanga  25.0  9.0  2021-09-25  16147.0          9.0
# 373452          Zacarias  25.0  9.0  2021-09-25    268.0          0.0
# 373453         Chavantes  25.0  9.0  2021-09-25   1388.0          0.0
# 373454      Estiva Gerbi  25.0  9.0  2021-09-25    811.0          0.0
# 374034               NaN   NaN  NaN         NaN      NaN          NaN
#
#             casos_pc         casos_mm7d  obitos  obitos_novos  ...  \
# ...

# %%
covid_alter.dtypes
# Out:
# Município          object
# dia               float64
# mes               float64
# Data               object
# casos             float64
# casos_novos       float64
# casos_pc          float64
# casos_mm7d         object
# obitos            float64
# obitos_novos      float64
# obitos_pc          object
# obitos_mm7d        object
# letalidade         object
# nome_ra            object
# nome_drs           object
# pop               float64
# pop_60            float64
# area              float64
# latitude           object
# longitude          object
# semana_epidem     float64
# Densidade /KM²    float64
# Índice              int64
# dtype: object

# %%
covid_alter
# Out:
#                Município   dia  mes        Data    casos  casos_novos  \
# 0             Adamantina  25.0  2.0  2020-02-25      0.0          0.0
# 1                 Adolfo  25.0  2.0  2020-02-25      0.0          0.0
# 2                  Aguaí  25.0  2.0  2020-02-25      0.0          0.0
# 3         Águas da Prata  25.0  2.0  2020-02-25      0.0          0.0
# 4       Águas de Lindóia  25.0  2.0  2020-02-25      0.0          0.0
# ...                  ...   ...  ...         ...      ...          ...
# 373451       Votuporanga  25.0  9.0  2021-09-25  16147.0          9.0
# 373452          Zacarias  25.0  9.0  2021-09-25    268.0          0.0
# 373453         Chavantes  25.0  9.0  2021-09-25   1388.0          0.0
# 373454      Estiva Gerbi  25.0  9.0  2021-09-25    811.0          0.0
# 374034               NaN   NaN  NaN         NaN      NaN          NaN
#
#             casos_pc         casos_mm7d  obitos  obitos_novos  ...  \
# ...

# %%
colunas_alteração = ['obitos_pc','obitos_mm7d','letalidade']

for i in  colunas_alteração:
    covid_alter[i] = covid_alter[i].astype(str).str.replace(',','.')

covid_alter
# Out:
# C:\Users\guico\AppData\Local\Temp\ipykernel_22820\778819426.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_alter[i] = covid_alter[i].astype(str).str.replace(',','.')
# C:\Users\guico\AppData\Local\Temp\ipykernel_22820\778819426.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_alter[i] = covid_alter[i].astype(str).str.replace(',','.')
# C:\Users\guico\AppData\Local\Temp\ipykernel_22820\778819426.py:4: SettingWithCopyWarning:
# ...

# %%
colunas_alteração = ['obitos_pc','obitos_mm7d','letalidade']

for i in  colunas_alteração:
    covid_alter[i] = covid_alter[i].astype(float)

covid_alter
# Out:
# C:\Users\guico\AppData\Local\Temp\ipykernel_22820\2163830484.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_alter[i] = covid_alter[i].astype(float)
# C:\Users\guico\AppData\Local\Temp\ipykernel_22820\2163830484.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_alter[i] = covid_alter[i].astype(float)
# C:\Users\guico\AppData\Local\Temp\ipykernel_22820\2163830484.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
covid_alter.dtypes
# Out:
# Município          object
# dia               float64
# mes               float64
# Data               object
# casos             float64
# casos_novos       float64
# casos_pc          float64
# casos_mm7d         object
# obitos            float64
# obitos_novos      float64
# obitos_pc         float64
# obitos_mm7d       float64
# letalidade        float64
# nome_ra            object
# nome_drs           object
# pop               float64
# pop_60            float64
# area              float64
# latitude           object
# longitude          object
# semana_epidem     float64
# Densidade /KM²    float64
# Índice              int64
# dtype: object

# %%
covid_alter['casos_mm7d'] = covid_alter['casos_mm7d'].astype(str).str.replace(',','.').astype(float)
#covid_alter['casos_mm7d'] = covid_alter['casos_mm7d'].as
# Out:
# C:\Users\guico\AppData\Local\Temp\ipykernel_22820\2398698513.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_alter['casos_mm7d'] = covid_alter['casos_mm7d'].astype(str).str.replace(',','.').astype(float)

# %%
covid_alter
# Out:
#                Município   dia  mes        Data    casos  casos_novos  \
# 0             Adamantina  25.0  2.0  2020-02-25      0.0          0.0
# 1                 Adolfo  25.0  2.0  2020-02-25      0.0          0.0
# 2                  Aguaí  25.0  2.0  2020-02-25      0.0          0.0
# 3         Águas da Prata  25.0  2.0  2020-02-25      0.0          0.0
# 4       Águas de Lindóia  25.0  2.0  2020-02-25      0.0          0.0
# ...                  ...   ...  ...         ...      ...          ...
# 373451       Votuporanga  25.0  9.0  2021-09-25  16147.0          9.0
# 373452          Zacarias  25.0  9.0  2021-09-25    268.0          0.0
# 373453         Chavantes  25.0  9.0  2021-09-25   1388.0          0.0
# 373454      Estiva Gerbi  25.0  9.0  2021-09-25    811.0          0.0
# 374034               NaN   NaN  NaN         NaN      NaN          NaN
#
#             casos_pc  casos_mm7d  obitos  obitos_novos  ...  \
# 0           0.000000    0.000000     0.0           0.0  ...
# ...

# %%
covid_alter.dropna()
# Out:
#                Município   dia  mes        Data    casos  casos_novos  \
# 0             Adamantina  25.0  2.0  2020-02-25      0.0          0.0
# 1                 Adolfo  25.0  2.0  2020-02-25      0.0          0.0
# 2                  Aguaí  25.0  2.0  2020-02-25      0.0          0.0
# 3         Águas da Prata  25.0  2.0  2020-02-25      0.0          0.0
# 4       Águas de Lindóia  25.0  2.0  2020-02-25      0.0          0.0
# ...                  ...   ...  ...         ...      ...          ...
# 373450        Votorantim  25.0  9.0  2021-09-25  11670.0          1.0
# 373451       Votuporanga  25.0  9.0  2021-09-25  16147.0          9.0
# 373452          Zacarias  25.0  9.0  2021-09-25    268.0          0.0
# 373453         Chavantes  25.0  9.0  2021-09-25   1388.0          0.0
# 373454      Estiva Gerbi  25.0  9.0  2021-09-25    811.0          0.0
#
#             casos_pc  casos_mm7d  obitos  obitos_novos  ...  \
# 0           0.000000    0.000000     0.0           0.0  ...
# ...

# %%
covid_alter['Data'] = pd.to_datetime(covid_alter['Data'])
covid_alter.dtypes
# Out:
# C:\Users\guico\AppData\Local\Temp\ipykernel_22820\2901646191.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_alter['Data'] = pd.to_datetime(covid_alter['Data'])
# Município                 object
# dia                      float64
# mes                      float64
# Data              datetime64[ns]
# casos                    float64
# casos_novos              float64
# casos_pc                 float64
# casos_mm7d               float64
# obitos                   float64
# obitos_novos             float64
# obitos_pc                float64
# obitos_mm7d              float64
# letalidade               float64
# nome_ra                   object
# nome_drs                  object
# pop                      float64
# ...

# %%
covid_alter
# Out:
#                Município   dia  mes       Data    casos  casos_novos  \
# 0             Adamantina  25.0  2.0 2020-02-25      0.0          0.0
# 1                 Adolfo  25.0  2.0 2020-02-25      0.0          0.0
# 2                  Aguaí  25.0  2.0 2020-02-25      0.0          0.0
# 3         Águas da Prata  25.0  2.0 2020-02-25      0.0          0.0
# 4       Águas de Lindóia  25.0  2.0 2020-02-25      0.0          0.0
# ...                  ...   ...  ...        ...      ...          ...
# 373451       Votuporanga  25.0  9.0 2021-09-25  16147.0          9.0
# 373452          Zacarias  25.0  9.0 2021-09-25    268.0          0.0
# 373453         Chavantes  25.0  9.0 2021-09-25   1388.0          0.0
# 373454      Estiva Gerbi  25.0  9.0 2021-09-25    811.0          0.0
# 374034               NaN   NaN  NaN        NaT      NaN          NaN
#
#             casos_pc  casos_mm7d  obitos  obitos_novos  ...  \
# 0           0.000000    0.000000     0.0           0.0  ...
# ...

# %% [markdown]
# ##### Salvando o projeto

# %%
covid_alter.to_csv('Covid_Alterado.csv', sep=';', encoding='utf-8', index=False)
