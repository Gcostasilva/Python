# %% [markdown]
# # Análise E-Comerce Brasil Olist

# %% [markdown]
# ## Importação

# %%
import pandas as pd

# Origem https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce


costumer = pd.read_csv('olist_customers_dataset.csv')
local = pd.read_csv('olist_geolocation_dataset.csv')
order_items = pd.read_csv('olist_order_items_dataset.csv')
order_payments = pd.read_csv('olist_order_payments_dataset.csv')
order_reviews = pd.read_csv('olist_order_reviews_dataset.csv')
orders = pd.read_csv('olist_orders_dataset.csv')
products = pd.read_csv('olist_products_dataset.csv')
sellers = pd.read_csv('olist_sellers_dataset.csv')
category_name_translation = pd.read_csv('product_category_name_translation.csv')

# %%
df = orders.merge(order_items, how='left', on='order_id')
df.shape
# Out:
# (113425, 14)

# %%
sdf = df.merge(order_payments,  how='left', on='order_id')
df.shape
# Out:
# (113425, 14)

# %%
df = df.merge(sellers,  how='left', on='seller_id')
df.shape
# Out:
# (113425, 17)

# %%
df = df.merge(costumer, how='left', on='customer_id')
df.shape
# Out:
# (113425, 21)

# %%
df = df.merge(products, how='left', on='product_id')
df.shape
# Out:
# (113425, 29)

# %%
df = df.merge(category_name_translation, how='left', on='product_category_name')
df.shape
# Out:
# (113425, 30)

# %% [markdown]
# ##

# %%
df.describe()
# Out:
#        order_item_id          price  freight_value  seller_zip_code_prefix  \
# count  112650.000000  112650.000000  112650.000000           112650.000000
# mean        1.197834     120.653739      19.990320            24439.170431
# std         0.705124     183.633928      15.806405            27596.030909
# min         1.000000       0.850000       0.000000             1001.000000
# 25%         1.000000      39.900000      13.080000             6429.000000
# 50%         1.000000      74.990000      16.260000            13568.000000
# 75%         1.000000     134.900000      21.150000            27930.000000
# max        21.000000    6735.000000     409.680000            99730.000000
#
#        customer_zip_code_prefix  product_name_lenght  \
# count             113425.000000        111047.000000
# mean               35102.472965            48.775978
# std                29864.919733            10.025581
# min                 1003.000000             5.000000
# 25%                11250.000000            42.000000
# 50%                24320.000000            52.000000
# 75%                59020.000000            57.000000
# max                99990.000000            76.000000
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# count               111047.000000       111047.000000     112632.000000
# mean                   787.867029            2.209713       2093.672047
# std                    652.135608            1.721438       3751.596884
# min                      4.000000            1.000000          0.000000
# 25%                    348.000000            1.000000        300.000000
# 50%                    603.000000            1.000000        700.000000
# 75%                    987.000000            3.000000       1800.000000
# max                   3992.000000           20.000000      40425.000000
#
#        product_length_cm  product_height_cm  product_width_cm
# count      112632.000000      112632.000000     112632.000000
# mean           30.153669          16.593766         22.996546
# std            16.153449          13.443483         11.707268
# min             7.000000           2.000000          6.000000
# 25%            18.000000           8.000000         15.000000
# 50%            25.000000          13.000000         20.000000
# 75%            38.000000          20.000000         30.000000
# max           105.000000         105.000000        118.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113425 entries, 0 to 113424
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       113425 non-null  object
#  1   customer_id                    113425 non-null  object
#  2   order_status                   113425 non-null  object
#  3   order_purchase_timestamp       113425 non-null  object
#  4   order_approved_at              113264 non-null  object
#  5   order_delivered_carrier_date   111457 non-null  object
#  6   order_delivered_customer_date  110196 non-null  object
#  7   order_estimated_delivery_date  113425 non-null  object
#  8   order_item_id                  112650 non-null  float64
#  9   product_id                     112650 non-null  object
#  10  seller_id                      112650 non-null  object
#  11  shipping_limit_date            112650 non-null  object
#  12  price                          112650 non-null  float64
#  13  freight_value                  112650 non-null  float64
#  14  seller_zip_code_prefix         112650 non-null  float64
#  15  seller_city                    112650 non-null  object
#  16  seller_state                   112650 non-null  object
#  17  customer_unique_id             113425 non-null  object
#  18  customer_zip_code_prefix       113425 non-null  int64
#  19  customer_city                  113425 non-null  object
#  20  customer_state                 113425 non-null  object
#  21  product_category_name          111047 non-null  object
#  22  product_name_lenght            111047 non-null  float64
#  23  product_description_lenght     111047 non-null  float64
#  24  product_photos_qty             111047 non-null  float64
#  25  product_weight_g               112632 non-null  float64
#  26  product_length_cm              112632 non-null  float64
#  27  product_height_cm              112632 non-null  float64
#  28  product_width_cm               112632 non-null  float64
#  29  product_category_name_english  111023 non-null  object
# dtypes: float64(11), int64(1), object(18)
# memory usage: 26.0+ MB

# %%
df.select_dtypes(include=['number']).corr()
# Out:
#                             order_item_id     price  freight_value  \
# order_item_id                    1.000000 -0.060522      -0.029380
# price                           -0.060522  1.000000       0.414204
# freight_value                   -0.029380  0.414204       1.000000
# seller_zip_code_prefix          -0.018721  0.086416       0.150204
# customer_zip_code_prefix        -0.000874  0.042467       0.225690
# product_name_lenght             -0.022662  0.017001       0.023611
# product_description_lenght      -0.014311  0.198166       0.093855
# product_photos_qty              -0.055852  0.051848       0.022259
# product_weight_g                -0.003549  0.338819       0.610420
# product_length_cm                0.005628  0.145811       0.309086
# product_height_cm                0.029323  0.223602       0.391831
# product_width_cm                -0.010732  0.172467       0.323777
#
#                             seller_zip_code_prefix  customer_zip_code_prefix  \
# order_item_id                            -0.018721                 -0.000874
# price                                     0.086416                  0.042467
# freight_value                             0.150204                  0.225690
# seller_zip_code_prefix                    1.000000                  0.076078
# customer_zip_code_prefix                  0.076078                  1.000000
# product_name_lenght                      -0.031412                  0.015515
# product_description_lenght                0.059581                  0.023709
# product_photos_qty                       -0.045357                  0.019626
# product_weight_g                          0.009709                  0.003242
# product_length_cm                         0.033426                  0.007491
# product_height_cm                         0.012570                  0.011746
# product_width_cm                         -0.016362                 -0.008723
#
#                             product_name_lenght  product_description_lenght  \
# order_item_id                         -0.022662                   -0.014311
# price                                  0.017001                    0.198166
# freight_value                          0.023611                    0.093855
# seller_zip_code_prefix                -0.031412                    0.059581
# customer_zip_code_prefix               0.015515                    0.023709
# product_name_lenght                    1.000000                    0.091524
# product_description_lenght             0.091524                    1.000000
# product_photos_qty                     0.145904                    0.118087
# product_weight_g                       0.022731                    0.059710
# product_length_cm                      0.060447                    0.005971
# product_height_cm                     -0.028170                    0.072724
# product_width_cm                       0.064442                   -0.068419
#
#                             product_photos_qty  product_weight_g  \
# order_item_id                        -0.055852         -0.003549
# price                                 0.051848          0.338819
# freight_value                         0.022259          0.610420
# seller_zip_code_prefix               -0.045357          0.009709
# customer_zip_code_prefix              0.019626          0.003242
# product_name_lenght                   0.145904          0.022731
# product_description_lenght            0.118087          0.059710
# product_photos_qty                    1.000000          0.022667
# product_weight_g                      0.022667          1.000000
# product_length_cm                     0.047503          0.460919
# product_height_cm                    -0.033399          0.583277
# product_width_cm                      0.010367          0.506609
#
#                             product_length_cm  product_height_cm  \
# order_item_id                        0.005628           0.029323
# price                                0.145811           0.223602
# freight_value                        0.309086           0.391831
# seller_zip_code_prefix               0.033426           0.012570
# customer_zip_code_prefix             0.007491           0.011746
# product_name_lenght                  0.060447          -0.028170
# product_description_lenght           0.005971           0.072724
# product_photos_qty                   0.047503          -0.033399
# product_weight_g                     0.460919           0.583277
# product_length_cm                    1.000000           0.192895
# product_height_cm                    0.192895           1.000000
# product_width_cm                     0.532537           0.281224
#
#                             product_width_cm
# order_item_id                      -0.010732
# price                               0.172467
# freight_value                       0.323777
# seller_zip_code_prefix             -0.016362
# customer_zip_code_prefix           -0.008723
# product_name_lenght                 0.064442
# product_description_lenght         -0.068419
# product_photos_qty                  0.010367
# product_weight_g                    0.506609
# product_length_cm                   0.532537
# product_height_cm                   0.281224
# product_width_cm                    1.000000
